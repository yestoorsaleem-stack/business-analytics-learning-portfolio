# %% [markdown]
# ## Python Basic

# %%
print('Hello world')   ## i am printing a simple statement
# Out:
# Hello world

# %%
print("""Python's
the best
!""")
# Out:
# Python's
# the best
# !

# %%
print("Python's the best!")
# Out:
# Python's the best!

# %%
 # Single line comments

# %%
# Single line comments
# 


''' jkgk
cjhgkj
gcjkh
hgdjhgkh
gchjg,khj
gdjhgj
c '''

'''multi-line 
comments'''


'''             basic functions of python
                    print statements
                    variables
                    user input etc
                    '''
# Out:
# '             basic functions of python\n                    print statements\n                    variables\n                    user input etc\n                    '

# %%
print("""One
two
three
fojhvvhf""")
# Out:
# One
# two
# three
# fojhvvhf

# %%
print('The cat says "meow." ')
# Out:
# The cat says "meow."

# %%
Gross_Pay = 500
a=5
b=7
print(a)
# Out:
# 5

# %%
print(Gross_Pay)
print(a)
b
# Out:
# 500
# 5
# 7

# %%
## Rules for naming variables 
### no spacing requir2ed
### first letter should be a to z OR A to Z or _
### uppercase and lowercase are different
### names should reflect the indication of what they are used for
### use gross_pay instead of grosspay

# %%
# Declaring variables
age = 20
print(age)
# Out:
# 20

# %%
# this program will display the age of Ali
print("age of Ali is ")
print(age)
# Out:
# age of Ali is
# 20

# %%
## assign the value 50 to length 3 to width of a square  


length = 50
width = 3

print("length of a square is ")
print(length)
print("width of the square is ")
print(width)
# Out:
# length of a square is
# 50
# width of the square is
# 3

# %%
print("length of square is ",length)
print("widht of square is ",width)
# Out:
# length of square is  50
# widht of square is  3

# %%
print("length and width of a square is ",length,"and",width,"respectively")
print(f'length and width of a square is {length} and {width} respectively')
# Out:
# length and width of a square is  50 and 3 respectively
# length and width of a square is 50 and 3 respectively

# %%
## Variable re-assignment

a=5
print(a)

a=6

a=7
print(a)
# Out:
# 5
# 7

# %% [markdown]
# ### Displaying Formatted Output with F-strings
#
#  An __f-string__ can contain placeholders for variables and other valid expressions.

# %%
print(f'Hello world')

temperature = 45
print(f'It is currently {temperature * 2} degrees.')

print(f'The value is {10 + 2}.')

val = 10
print(f'The value is {val + 2}.')
# Out:
# Hello world
# It is currently 90 degrees.
# The value is 12.
# The value is 12.

# %% [markdown]
# ### Formatting Values

# %%
amount = 12.9876
print(f'Amount is {amount:.2f}')

marks = 0.56
print(f'Percentage = {marks:%}')

print(f'Percentage = {marks:.0%}')
# Out:
# Amount is 12.99
# Percentage = 56.000000%
# Percentage = 56%

# %% [markdown]
# ## Data Types

# %%
## Data Types and Literals
## int = 5,100,-9
## float = 1.5, -2.75
## string = Bilal

a = 4.3


print(type(100))
print(type(2.75))
type(a)
# Out:
# <class 'int'>
# <class 'float'>
# float

# %%
type(2.4)
# Out:
# float

# %%
x = 2.6
print(x)
y = int(x)
print(y)
# Out:
# 2.6
# 2

# %%
pvalue = 3
gvalue = float(pvalue)
print(gvalue)
type(pvalue)
# Out:
# 3.0
# int

# %%
## Mathematical operations 

x=25
y=5

print(x+y)

print(x-y)

print(x*y)  

print(x/y)

print(x%y)

print(x//y)

print(x**2)
# Out:
# 30
# 20
# 125
# 5.0
# 0
# 5
# 625

# %%
original_price=250
discount_rate = 0.20
discount = original_price * discount_rate
discounted_price = original_price - discount
print("the price after discount is ",discounted_price)
print(f'discounted price is {discounted_price:.0f}')
# Out:
# the price after discount is  200.0
# discounted price is 200

# %%
## String varibales

first_name = 'Bilal'
last_name = 'Qaisar'

print(first_name,last_name)
# Out:
# Bilal Qaisar

# %%
# string concatenation: String concatenation is the appending of one string to the end of another.
f_name = 'Bilal '
l_name ='Qaisar'
full_name = f_name + l_name
print(full_name)
# Out:
# Bilal Qaisar

# %%
print('Enter the amount of' +
     'weekly sales in the required columns and '+
     'Press enter')
# Out:
# Enter the amount ofweekly sales in the required columns and Press enter

# %%
result = '1' +  '2'
print(result)
# Out:
# 12

# %%
result = '1' + ' ' '2'
print(result)
# Out:
# 1 2

# %% [markdown]
# ## Input Command

# %%
## Input variables 
name = input("what is your name? ")
print('my name is ',name)
# Out:
# what is your name? Bilal Qaisar
# my name is  Bilal Qaisar

# %%
## input the integers or float numbers

string_val = int(input("write the number of hours worked "))
string_val + 4
# Out:
# write the number of hours worked 14
# 18

# %%
no_of_hours_worked = int(input("how many hours did you work? "))
print("no of hours worked by an emplyoyee = ",no_of_hours_worked)
# Out:
# how many hours did you work? 5
# no of hours worked by an emplyoyee =  5

# %%
no_of_sales = float(input("what are the total number of week sales? "))
print("total weekly sales are ",no_of_sales)
# Out:
# what are the total number of week sales? 25.5
# total weekly sales are  25.5

# %%
leftover = (5//2) 
print(leftover)
# Out:
# 2

# %% [markdown]
# ## Question

# %%
##  write a program to calculate the sale price of an item after the discount is subtracted given the 20% discount rate

# %%
original_price=250
discount_rate = 0.20
discount = original_price * discount_rate
discounted_price = original_price - discount
print("the price after discount is ",discounted_price)
print(f'discounted price is {discounted_price:.0f}')
# Out:
# the price after discount is  200.0
# discounted price is 200

# %%
## Question no 2 
total_sales = float(input("enter the amount of total sales "))
profit = total_sales * 0.23 
print("total profit is ",profit)
# Out:
# enter the amount of total sales 25
# total profit is  5.75

# %% [markdown]
# ## Escape Characters

# %%
print("one\ntwo")
# Out:
# one
# two

# %%
print("one\ttwo")
# Out:
# one	two

# %%
print("one\'two")
# Out:
# one'two

# %%
print("one\"two")
# Out:
# one"two

# %%
print("one\\two")
# Out:
# one\two

# %%
seconds = 594
rem_min = (seconds // 60) % 60  ## first seconds are converted into minutes using // sign. then divided by 60 using % to have the remaing minutes
rem_sec = seconds % 60

# %% [markdown]
# ## Practice Exercise

# %% [markdown]
# ''''
# Display your name and address on screen
#
# Write a statement that displays the following text:
# The cat said "meow."
# Python's the best!
#
# Assign 68 to Fahrenheit and  20 to Celsius and print both temperature values.
#
# Change the data type of any value from integer to float.
#
# Write a program that first prompts user to input their first and last name and then display full name
# using string concatenation
#
# Write a program that prompts the user to enter the marks for three different subjects and then calculate the
# average of the student
#
#
# ''''

# %%
# Get the user's name, age, and income.
name = input('What is your name? ')
age = int(input('What is your age? '))
income = float(input('What is your income? '))
# Display the data.
print('Here is the data you entered:')
print('Name:', name)
print('Age:', age)
print('Income:', income)
# Out:
# What is your name? Bilal Qaisar
# What is your age? 37
# What is your income? 100000
# Here is the data you entered:
# Name: Bilal Qaisar
# Age: 37
# Income: 100000.0

# %%
sub_1 = int(input("enter the marks for first subject "))
sub_2 = int(input("enter the marks for second subject "))
sub_3 = int(input("enter the marks for third subject "))
average = (sub_1+sub_2+sub_3)/3
print(f'Average of three subjects is {average:.2f}')
# Out:
# enter the marks for first subject 150
# enter the marks for second subject 110
# enter the marks for third subject 300
# Average of three subjects is 186.67

# %%
yearly_sales = float(input("Enter the amount of yearly sales "))
monthly_sales = yearly_sales/12
print(f'Monthly sale is {monthly_sales:.2f}')
# Out:
# Enter the amount of yearly sales 45398
# Monthly sale is 3783.17

# %%
## Q 4
I_1 = 3
I_2 =5
I_3 =6
I_4 = 5
I_5 = 7
sales_total = (I_1 + I_2 + I_3 + I_4 + I_5)
print("total subtotal sales are ", sales_total)
tax_rate = 0.07
sales_tax_amount = tax_rate * sales_total 
total_sales_inc_tax = sales_total + sales_tax_amount
print("total sales including tax is ",total_sales_inc_tax )
# Out:
# total subtotal sales are  26
# total sales including tax is  27.82

# %%
## Q6
purchase_amount = float(input("enter the amount of purchase "))
state_tax_rate = 0.05
county_tax_rate = 0.025

state_sales_tax = state_tax_rate * purchase_amount
county_sales_tax = county_tax_rate * purchase_amount

total_sales_tax = state_sales_tax + county_sales_tax
total_sales = purchase_amount + total_sales_tax

print("purchase amount is ", purchase_amount)
print("state sales tax is ",state_sales_tax )
print("county sales tax is ",county_sales_tax)
print("total sales tax is ", total_sales_tax)
print(" total sales are ",total_sales)
# Out:
# enter the amount of purchase 25000
# purchase amount is  25000.0
# state sales tax is  1250.0
# county sales tax is  625.0
# total sales tax is  1875.0
#  total sales are  26875.0

# %%
print('The path is \n\tC:\\temp\\data.')
# Out:
# The path is
# 	C:\temp\data.

# %%
print('Mon\tTues\tWed\nThur\tFri\tSat\t')
# Out:
# Mon	Tues	Wed
# Thur	Fri	Sat

# %%
print('One\nTwo\nThree')
# Out:
# One
# Two
# Three

# %%
f_name = input("enter your first name  ")
l_name = input("enter your last name  ")

full_name = f_name + ' '+ l_name

print(f'Full name is {full_name}')
# Out:
# enter your first name  Bilal
# enter your last name  Qaisar
# Full name is Bilal Qaisar

# %% [markdown]
# # Chapter 3

# %%
sub_1 = int(input("enter the marks for first subject "))
sub_2 = int(input("enter the marks for second subject "))
sub_3 = int(input("enter the marks for third subject "))
average = (sub_1+sub_2+sub_3)/3
print("average is ",average)
if average > 80:
    print("this is the great average")
else:
    print("you need to work hard")
# Out:
# enter the marks for first subject 45
# enter the marks for second subject 46
# enter the marks for third subject 78
# average is  56.333333333333336
# you need to work hard

# %%
base_hours = 40
Overtime_multiplier = 1.5

hours_worked = float(input("enter the total number of hours worked "))
pay_rate = float(input("enter the hourly pay rate "))

if hours_worked > base_hours:
    overtime_hours_worked = hours_worked - base_hours    ## Calculate the overtime hours worked
    
    overtime_pay = overtime_hours_worked * pay_rate * Overtime_multiplier  
    
    Gross_pay = (base_hours * pay_rate) + overtime_pay 
    
else:
    Gross_pay = hours_worked * pay_rate
          
    

print(f'Gross pay is {Gross_pay}')
# Out:
# enter the total number of hours worked 50
# enter the hourly pay rate 2
# Gross pay is 110.0
